# %%
G=5
w=0.1
G1=0.01
gamma=0.0001
# Out:
# 5
# 0.1
# 0.01
# 0.0001

# %%
eq=x^4-(24*x^2/(90*w))+(gamma^2*x^2)/(90*w^2)-(4*gamma*G*x/(90*G1*w^2))-4/(90*w^2)==0
# Out:
#                                  2    4
# -4.44444 - 0.222222 x - 2.66667 x  + x  == 0

# %%
rts=Solve[{eq},{x}];
hrts=N[rts,50]
# Out:
# {{x -> -1.93393}, {x -> -0.0222765 - 1.07753 I}, {x -> -0.0222765 + 1.07753 I},
#
# >   {x -> 1.97848}}

# %%
InputForm[hrts[[4]]]
# Out:
# {x -> 1.9784832889048005}

# %%
f[x_]=x^4-(24*x^2/(90*w))+(gamma^2*x^2)/(90*w^2)-(4*gamma*G*x/(90*G1*w^2))-4/(90*w^2)
# Out:
#                                   2    4
# -4.44444 - 0.0222222 x - 2.66667 x  + x

# %%
f[1.9586937232350317]
# Out:
#            -15
# -1.77636 10

# %%
Plot[f[x],{x,1,2},PlotRange -> Automatic]
# Out:
# -Graphics-
